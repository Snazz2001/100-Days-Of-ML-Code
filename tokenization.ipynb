# %% [markdown]
# <a href="https://colab.research.google.com/github/Snazz2001/100-Days-Of-ML-Code/blob/master/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import AutoTokenizer

# Load a pre-trained tokenizer
model_name = "meta-llama/Meta-Llama-3-8B"  # deepseek-ai/DeepSeek-V2"
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize a text
text = "The quick brown fox jumps over the lazy dog!"

encoded_text = tokenizer(text)

# Access the tokenized IDs
print(tokenizer.decode(encoded_text["input_ids"]))

print(encoded_text["input_ids"])
print(", ".join([tokenizer.decode(t) for t in encoded_text["input_ids"]]))
# Out:
# [CLS] the quick brown fox jumps over the lazy dog! [SEP]
# [101, 1996, 4248, 2829, 4419, 14523, 2058, 1996, 13971, 3899, 999, 102]
# [CLS], the, quick, brown, fox, jumps, over, the, lazy, dog, !, [SEP]

# %%
# !pip install langchain_core langchain langchain_community langchain-text-splitters langchain-experimental
# Out:
# ...
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.1/210.1 kB 17.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.9/484.9 kB 26.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain_core
#     Found existing installation: langchain-core 1.2.1
#     Uninstalling langchain-core-1.2.1:
#       Successfully uninstalled langchain-core-1.2.1
# ...

# %%
from langchain_core.runnables import RunnableLambda
runnable = RunnableLambda(lambda x: x**2)
runnable.invoke(3)
# Out:
# 9

# %%
from typing import Optional
from langchain_core.runnables import Runnable, RunnableConfig, RunnableLambda, RunnableParallel
from langchain_core.output_parsers import StrOutputParser

def increment_x_by_one(x: int) -> int:
    return x + 1

def fake_llm(x: int) -> str:
    return f"Result = {x}"

class MyFirstChain(Runnable[int, str]):
  def invoke(self, input:str, config: Optional[RunnableConfig]=None)->str:
    increment = increment_x_by_one(input)
    return fake_llm(increment)

# %%
runnable=MyFirstChain()
response=runnable.invoke(3)
print(response)
# Out:
# Result = 4

# %%
chain = (RunnableLambda(increment_x_by_one) | RunnableLambda(fake_llm))
chain.invoke(3)
# Out:
# 'Result = 4'

# %%
chain = RunnableParallel(step1 = (increment_x_by_one|RunnableLambda(fake_llm)),
                         step2= fake_llm)
chain.invoke(3)
# Out:
# {'step1': 'Result = 4', 'step2': 'Result = 3'}

# %%
chain1 = increment_x_by_one | chain
chain1.invoke(1)
# Out:
# {'step1': 'Result = 3', 'step2': 'Result = 2'}

# %%
from operator import itemgetter

chain = (itemgetter("x")|RunnableLambda(increment_x_by_one)|RunnableLambda(fake_llm))
chain.invoke({"x":1})
# Out:
# 'Result = 2'
